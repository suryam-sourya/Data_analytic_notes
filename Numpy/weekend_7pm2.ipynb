# %%
import numpy as np
import pandas as pd

# %%
l = [2,3,5,6]
l
# Out:
# [2, 3, 5, 6]

# %%
#l+2

# %%
x = np.array(l)
x
# Out:
# array([2, 3, 5, 6])

# %%
x+2
# Out:
# array([4, 5, 7, 8])

# %%
# array
# series

# %%
# series  - 1-d labelled array

# %%
l = [2,3,5,6]
l
# Out:
# [2, 3, 5, 6]

# %%
s = pd.Series(l , index = ["a",  "b" , "c" , "d"])
s
# Out:
# a    2
# b    3
# c    5
# d    6
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s["a"]
# Out:
# 2

# %%
s["c"]
# Out:
# 5

# %%
# Dataframe -> 2-d labelled array
# combination of series

# %%
df = pd.read_csv("stud.csv")
df.head()
# Out:
#    id   name  age gender  marks branch
# 0   1    Ram   24      m     95  civil
# 1   2  Shyam   23      m     80    eee
# 2   3   Sita   20      f     85     cs
# 3   4  Geeta   21      f     93    eee
# 4   5  Kamal   18      m     77     me

# %%
df["name"]
# Out:
# 0         Ram
# 1       Shyam
# 2        Sita
# 3       Geeta
# 4       Kamal
#        ...
# 95      Sneha
# 96      Sumit
# 97    Aarunya
# 98    Atharva
# 99      Kowid
# Name: name, Length: 100, dtype: object

# %%
type(df["name"])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# how to create dataframe

# %%
# 1.  from dict of list objects 

# here each key acts as column name and values is list of values for that column

# %%
import pandas as pd

l1 = [10,20,30,40]
l2 = ["nitin" , "tina" , "arun" ,"riya"]
l3 = [1000,2000,3000,4000]
l4 = ["doon" , "delhi" , "rishikesh" , "shimla"]

df2 = pd.DataFrame({"eno":l1 , "e name":l2 , "esal":l3 , "eadrs":l4})

df2
# Out:
#    eno e name  esal      eadrs
# 0   10  nitin  1000       doon
# 1   20   tina  2000      delhi
# 2   30   arun  3000  rishikesh
# 3   40   riya  4000     shimla

# %%
df2["e name"]
# Out:
# 0    nitin
# 1     tina
# 2     arun
# 3     riya
# Name: e name, dtype: object

# %%
df.e name
# Out:
#   Cell In[123], line 1
#     df.e name
#          ^
# SyntaxError: invalid syntax

# %%
# 2. from dict of tuple objects
# instead of list objects we can use tuple objects also

# %%
import pandas as pd

eno = (10,20,30,40)
ename = ("nitin" , "tina" , "arun" ,"riya")
esal = (1000,2000,3000,4000)
eadrs = ("doon" , "delhi" , "rishikesh" , "shimla")

df = pd.DataFrame({"eno":eno , "ename":ename , "esal":esal , "eadrs":eadrs})

df
# Out:
#    eno  ename  esal      eadrs
# 0   10  nitin  1000       doon
# 1   20   tina  2000      delhi
# 2   30   arun  3000  rishikesh
# 3   40   riya  4000     shimla

# %%
# 3. from dict of series objects

# dataframe is nothing bt collection of series objects

# %%
import pandas as pd

eno = pd.Series([10,20,30,40])
ename = pd.Series(["nitin" , "tina" , "arun" ,"riya"])
esal = pd.Series([1000,2000,3000,4000])
eadrs = pd.Series(["doon" , "delhi" , "rishikesh" , "shimla"])

df = pd.DataFrame({"eno":eno , "ename":ename , "esal":esal , "eadrs":eadrs})

df
# Out:
#    eno  ename  esal      eadrs
# 0   10  nitin  1000       doon
# 1   20   tina  2000      delhi
# 2   30   arun  3000  rishikesh
# 3   40   riya  4000     shimla

# %%
# 3. from dict of array objects

# dataframe is nothing bt collection of series objects

# %%
eno = np.array([10,20,30,40])
ename = np.array(["nitin" , "tina" , "arun" ,"riya"])
esal = np.array([1000,2000,3000,4000])
eadrs = np.array(["doon" , "delhi" , "rishikesh" , "shimla"])

df = pd.DataFrame({"eno":eno , "ename":ename , "esal":esal , "eadrs":eadrs})

df
# Out:
#    eno  ename  esal      eadrs
# 0   10  nitin  1000       doon
# 1   20   tina  2000      delhi
# 2   30   arun  3000  rishikesh
# 3   40   riya  4000     shimla

# %%
# from dict of dict

# %%
import pandas as pd

eno = {0:10,1:20,2:30,4:40}
ename = {0:"nitin" , 1:"tina" , 2:"arun" ,3:"riya"}
esal = {0:1000,1:2000,2:3000,3:4000 }
eadrs = {0:"doon" , 1:"delhi" , 2:"rishikesh" , 3:"shimla"}

df = pd.DataFrame({"eno":eno , "ename":ename , "esal":esal , "eadrs":eadrs})

df
# Out:
#     eno  ename    esal      eadrs
# 0  10.0  nitin  1000.0       doon
# 1  20.0   tina  2000.0      delhi
# 2  30.0   arun  3000.0  rishikesh
# 4  40.0    NaN     NaN        NaN
# 3   NaN   riya  4000.0     shimla

# %%
# 5. from list of dicts

# %%
import pandas as pd

d1 = {"eno":10, "ename":"tina" , "esal":1000 , "eadrs":"rishikesh"}

d2 = {"eno":20, "ename":"nitin" , "esal":2000 , "eadrs":"delhi"}

d3 = {"eno":30, "ename":"riya" , "esal":3000 , "eadrs":"doon"}

d4 = {"eno":40, "ename":"sachin" , "esal":4000 , "eadrs":"shimla"}

l = [d1,d2,d3,d4]

df = pd.DataFrame(l)

df
# Out:
#    eno   ename  esal      eadrs
# 0   10    tina  1000  rishikesh
# 1   20   nitin  2000      delhi
# 2   30    riya  3000       doon
# 3   40  sachin  4000     shimla

# %%
# list of list

# %%
import pandas as pd
l1 = [10,20,30,40]
l2 = ["nitin" , "tina" , "arun" ,"riya"]
l3 = [1000,2000,3000,4000]
l4 = ["doon" , "delhi" , "rishikesh" , "shimla"]

df = pd.DataFrame([l1,l2,l3,l4] ,columns  = ["a"  , "b" , "c" , "d"] )

df
# Out:
#        a      b          c       d
# 0     10     20         30      40
# 1  nitin   tina       arun    riya
# 2   1000   2000       3000    4000
# 3   doon  delhi  rishikesh  shimla

# %%
# head()
# tail()

# %%
df1 = pd.read_csv("stud.csv")

# %%
df1
# Out:
#      id     name  age gender  marks branch
# 0     1      Ram   24      m     95  civil
# 1     2    Shyam   23      m     80    eee
# 2     3     Sita   20      f     85     cs
# 3     4    Geeta   21      f     93    eee
# 4     5    Kamal   18      m     77     me
# ..  ...      ...  ...    ...    ...    ...
# 95   96    Sneha   32      f     59    eee
# 96   97    Sumit   34      m     50  civil
# 97   98  Aarunya   21      f     88  civil
# 98   99  Atharva   20      m     90     me
# 99  100    Kowid   21      m     92  civil
#
# [100 rows x 6 columns]

# %%
df = pd.read_csv(r"C:\Users\user\Desktop\ml\car_eda.csv")
df
# Out:
#       mpg   cylinders  cubicinches     hp  weightlbs   time-to-60   year  \
# 0    14.0           8          350  165.0       4209         12.0   1972
# 1    31.9           4           89   71.0       1925         14.0   1980
# 2    17.0           8          302  140.0       3449         11.0   1971
# 3    15.0           8          400  150.0       3761         10.0   1971
# 4    30.5           4           98   63.0       2051         17.0   1978
# ..    ...         ...          ...    ...        ...          ...    ...
# 256  17.0           8          305  130.0       3840         15.0   1980
# 257  36.1           4           91   60.0       1800         16.0   1979
# 258  22.0           6          232  112.0       2835         15.0   1983
# 259  18.0           6          232  100.0       3288         16.0   1972
# 260  22.0           6          250  105.0       3353         15.0   1977
#
#         brand
# 0         US.
# 1     Europe.
# 2         US.
# 3         US.
# ...

# %%
# head()
# tail()

# %%
df = pd.read_csv("stud.csv")

# %%
df
# Out:
#      id     name  age gender  marks branch
# 0     1      Ram   24      m     95  civil
# 1     2    Shyam   23      m     80    eee
# 2     3     Sita   20      f     85     cs
# 3     4    Geeta   21      f     93    eee
# 4     5    Kamal   18      m     77     me
# ..  ...      ...  ...    ...    ...    ...
# 95   96    Sneha   32      f     59    eee
# 96   97    Sumit   34      m     50  civil
# 97   98  Aarunya   21      f     88  civil
# 98   99  Atharva   20      m     90     me
# 99  100    Kowid   21      m     92  civil
#
# [100 rows x 6 columns]

# %%
# by default it display 5 rows

df.head()
# Out:
#    id   name  age gender  marks branch
# 0   1    Ram   24      m     95  civil
# 1   2  Shyam   23      m     80    eee
# 2   3   Sita   20      f     85     cs
# 3   4  Geeta   21      f     93    eee
# 4   5  Kamal   18      m     77     me

# %%
df.head(6)
# Out:
#    id        name  age gender  marks branch
# 0   1         Ram   24      m     95  civil
# 1   2       Shyam   23      m     80    eee
# 2   3        Sita   20      f     85     cs
# 3   4       Geeta   21      f     93    eee
# 4   5       Kamal   18      m     77     me
# 5   6  Parshu ram   30      m     65     cs

# %%
df.tail(6)
# Out:
#      id       name  age gender  marks branch
# 94   95  Parikshit   21      m     80     cs
# 95   96      Sneha   32      f     59    eee
# 96   97      Sumit   34      m     50  civil
# 97   98    Aarunya   21      f     88  civil
# 98   99    Atharva   20      m     90     me
# 99  100      Kowid   21      m     92  civil

# %%
df1 = pd.read_csv("students.csv")
df1
# Out:
#     id      name  marks
# 0    1     nitin    200
# 1    2      arun    300
# 2    3     pinky    400
# 3    4     simmi    500
# 4    5     tannu    400
# 5    6     kajal    800
# 6    7  himanshu    900
# 7    8      riya   1000
# 8    9      tina    400
# 9   10      sonu    500
# 10  11      anil   1000
# 11  12       ram    300
# 12  13      ritu    200
# 13  14   kaushal    800
# 14  15     padam    700
# 15  16    manish    200
# 16  17      renu    600
# 17  18      monu    300
# 18  19     ankit    200
# 19  20    pankaj    400

# %%
# except last 5 rows 
df.head(-5)
# Out:
#     id      name  marks
# 0    1     nitin    200
# 1    2      arun    300
# 2    3     pinky    400
# 3    4     simmi    500
# 4    5     tannu    400
# 5    6     kajal    800
# 6    7  himanshu    900
# 7    8      riya   1000
# 8    9      tina    400
# 9   10      sonu    500
# 10  11      anil   1000
# 11  12       ram    300
# 12  13      ritu    200
# 13  14   kaushal    800
# 14  15     padam    700

# %%
# except starting 5 rows
df.tail(-5)
# Out:
#     id      name  marks
# 5    6     kajal    800
# 6    7  himanshu    900
# 7    8      riya   1000
# 8    9      tina    400
# 9   10      sonu    500
# 10  11      anil   1000
# 11  12       ram    300
# 12  13      ritu    200
# 13  14   kaushal    800
# 14  15     padam    700
# 15  16    manish    200
# 16  17      renu    600
# 17  18      monu    300
# 18  19     ankit    200
# 19  20    pankaj    400

# %%
print(df.shape)
print(df.ndim)
print(df.size)
# Out:
# (20, 3)
# 2
# 60

# %%
df = pd.read_csv("stud.csv")
df
# Out:
#      id     name  age gender  marks branch
# 0     1      Ram   24      m     95  civil
# 1     2    Shyam   23      m     80    eee
# 2     3     Sita   20      f     85     cs
# 3     4    Geeta   21      f     93    eee
# 4     5    Kamal   18      m     77     me
# ..  ...      ...  ...    ...    ...    ...
# 95   96    Sneha   32      f     59    eee
# 96   97    Sumit   34      m     50  civil
# 97   98  Aarunya   21      f     88  civil
# 98   99  Atharva   20      m     90     me
# 99  100    Kowid   21      m     92  civil
#
# [100 rows x 6 columns]

# %%
df.shape
# Out:
# (100, 6)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 600

# %%
df
# Out:
#      id     name  age gender  marks branch
# 0     1      Ram   24      m     95  civil
# 1     2    Shyam   23      m     80    eee
# 2     3     Sita   20      f     85     cs
# 3     4    Geeta   21      f     93    eee
# 4     5    Kamal   18      m     77     me
# ..  ...      ...  ...    ...    ...    ...
# 95   96    Sneha   32      f     59    eee
# 96   97    Sumit   34      m     50  civil
# 97   98  Aarunya   21      f     88  civil
# 98   99  Atharva   20      m     90     me
# 99  100    Kowid   21      m     92  civil
#
# [100 rows x 6 columns]

# %%
# to get all column names
df.columns
# Out:
# Index(['id', 'name', 'age', 'gender', 'marks', 'branch'], dtype='object')

# %%
# get all index values
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
# get all values
df.values
# Out:
# array([[1, 'Ram', 24, 'm', 95, 'civil'],
#        [2, 'Shyam', 23, 'm', 80, 'eee'],
#        [3, 'Sita', 20, 'f', 85, 'cs'],
#        [4, 'Geeta', 21, 'f', 93, 'eee'],
#        [5, 'Kamal', 18, 'm', 77, 'me'],
#        [6, 'Parshu ram', 30, 'm', 65, 'cs'],
#        [7, 'Shiv', 35, 'm', 80, 'ec'],
#        [8, 'Sehwag', 31, 'm', 87, 'civil'],
#        [9, 'Gautam', 28, 'm', 97, 'cs'],
#        [10, 'Mitali', 34, 'f', 88, 'me'],
#        [11, 'Kapil', 25, 'm', 55, 'it'],
#        [12, 'Jhulan', 27, 'f', 64, 'me'],
#        [13, 'Neha', 23, 'f', 83, 'it'],
#        [14, 'Ravi', 35, 'm', 51, 'cs'],
#        [15, 'Arun', 34, 'm', 91, 'it'],
#        [16, 'Monu', 26, 'm', 76, 'me'],
#        [17, 'Aarti', 25, 'f', 88, 'civil'],
#        [18, 'Jyoti', 21, 'f', 85, 'cs'],
#        [19, 'Sonu', 32, 'm', 78, 'it'],
#        [20, 'Kirti', 28, 'f', 82, 'eee'],
#        [21, 'Mohit', 27, 'm', 74, 'civil'],
#        [22, 'sahil', 21, 'm', 66, 'it'],
#        [23, 'Varun', 31, 'm', 57, 'civil'],
# ...

# %%
df
# Out:
#      id     name  age gender  marks branch
# 0     1      Ram   24      m     95  civil
# 1     2    Shyam   23      m     80    eee
# 2     3     Sita   20      f     85     cs
# 3     4    Geeta   21      f     93    eee
# 4     5    Kamal   18      m     77     me
# ..  ...      ...  ...    ...    ...    ...
# 95   96    Sneha   32      f     59    eee
# 96   97    Sumit   34      m     50  civil
# 97   98  Aarunya   21      f     88  civil
# 98   99  Atharva   20      m     90     me
# 99  100    Kowid   21      m     92  civil
#
# [100 rows x 6 columns]

# %%
df.sample()
# Out:
#     id   name  age gender  marks branch
# 32  33  Mohan   33      m     55     cs

# %%
df.sample(5)
# Out:
#     id     name  age gender  marks branch
# 24  25  Shubham   26      m     65     it
# 21  22    sahil   21      m     66     it
# 68  69   Hardik   28      m     70     ec
# 10  11    Kapil   25      m     55     it
# 45  46    Kamal   24      m     77     ec

# %%
df.sample(frac = .25)
# Out:
#     id        name  age gender  marks branch
# 57  58     Aarunya   18      f     98     it
# 5    6  Parshu ram   30      m     65     cs
# 45  46       Kamal   24      m     77     ec
# 15  16        Monu   26      m     76     me
# 0    1         Ram   24      m     95  civil
# 79  80      Anjali   23      f     36     me
# 88  89        Sonu   27      m     68    eee
# 80  81       Rohan   25      m     49     it
# 82  83       Mohan   22      m     91     cs
# 84  85    Surender   34      m     74    eee
# 65  66    Mahender   35      m     77    eee
# 81  82       Sohan   25      m     68  civil
# 19  20       Kirti   28      f     82    eee
# 91  92       Kirti   26      f     78     me
# 2    3        Sita   20      f     85     cs
# 34  35    Surender   26      m     43    eee
# 94  95   Parikshit   21      m     80     cs
# 28  29    Priyanka   28      f     82     ec
# 7    8      Sehwag   31      m     87  civil
# 66  67       Virat   34      m     76     me
# ...

# %%
df1
# Out:
#     id      name  marks
# 0    1     nitin    200
# 1    2      arun    300
# 2    3     pinky    400
# 3    4     simmi    500
# 4    5     tannu    400
# 5    6     kajal    800
# 6    7  himanshu    900
# 7    8      riya   1000
# 8    9      tina    400
# 9   10      sonu    500
# 10  11      anil   1000
# 11  12       ram    300
# 12  13      ritu    200
# 13  14   kaushal    800
# 14  15     padam    700
# 15  16    manish    200
# 16  17      renu    600
# 17  18      monu    300
# 18  19     ankit    200
# 19  20    pankaj    400

# %%
df1.sample(frac = .25)
# Out:
#     id     name  marks
# 10  11     anil   1000
# 11  12      ram    300
# 18  19    ankit    200
# 15  16   manish    200
# 13  14  kaushal    800

# %%
df.head()
# Out:
#    id   name  age gender  marks branch
# 0   1    Ram   24      m     95  civil
# 1   2  Shyam   23      m     80    eee
# 2   3   Sita   20      f     85     cs
# 3   4  Geeta   21      f     93    eee
# 4   5  Kamal   18      m     77     me

# %%
# how to access columns

# %%
# df.column_name

# df["column_name"]

# %%
df.name
# Out:
# 0         Ram
# 1       Shyam
# 2        Sita
# 3       Geeta
# 4       Kamal
#        ...
# 95      Sneha
# 96      Sumit
# 97    Aarunya
# 98    Atharva
# 99      Kowid
# Name: name, Length: 100, dtype: object

# %%
df["name"]
# Out:
# 0         Ram
# 1       Shyam
# 2        Sita
# 3       Geeta
# 4       Kamal
#        ...
# 95      Sneha
# 96      Sumit
# 97    Aarunya
# 98    Atharva
# 99      Kowid
# Name: name, Length: 100, dtype: object

# %%
df.head()
# Out:
#    id   name  age gender  marks branch
# 0   1    Ram   24      m     95  civil
# 1   2  Shyam   23      m     80    eee
# 2   3   Sita   20      f     85     cs
# 3   4  Geeta   21      f     93    eee
# 4   5  Kamal   18      m     77     me

# %%
df[["name","marks","gender"]]
# Out:
#        name  marks gender
# 0       Ram     95      m
# 1     Shyam     80      m
# 2      Sita     85      f
# 3     Geeta     93      f
# 4     Kamal     77      m
# ..      ...    ...    ...
# 95    Sneha     59      f
# 96    Sumit     50      m
# 97  Aarunya     88      f
# 98  Atharva     90      m
# 99    Kowid     92      m
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    id   name  age gender  marks branch
# 0   1    Ram   24      m     95  civil
# 1   2  Shyam   23      m     80    eee
# 2   3   Sita   20      f     85     cs
# 3   4  Geeta   21      f     93    eee
# 4   5  Kamal   18      m     77     me

# %%
df["age"]+10
# Out:
# 0     34
# 1     33
# 2     30
# 3     31
# 4     28
#       ..
# 95    42
# 96    44
# 97    31
# 98    30
# 99    31
# Name: age, Length: 100, dtype: int64

# %%
df
# Out:
#      id     name  age gender  marks branch
# 0     1      Ram   24      m     95  civil
# 1     2    Shyam   23      m     80    eee
# 2     3     Sita   20      f     85     cs
# 3     4    Geeta   21      f     93    eee
# 4     5    Kamal   18      m     77     me
# ..  ...      ...  ...    ...    ...    ...
# 95   96    Sneha   32      f     59    eee
# 96   97    Sumit   34      m     50  civil
# 97   98  Aarunya   21      f     88  civil
# 98   99  Atharva   20      m     90     me
# 99  100    Kowid   21      m     92  civil
#
# [100 rows x 6 columns]

# %%
df[["age" , "marks"]]+10
# Out:
#     age  marks
# 0    34    105
# 1    33     90
# 2    30     95
# 3    31    103
# 4    28     87
# ..  ...    ...
# 95   42     69
# 96   44     60
# 97   31     98
# 98   30    100
# 99   31    102
#
# [100 rows x 2 columns]

# %%
df["age"].add(10)
# Out:
# 0     34
# 1     33
# 2     30
# 3     31
# 4     28
#       ..
# 95    42
# 96    44
# 97    31
# 98    30
# 99    31
# Name: age, Length: 100, dtype: int64

# %%
# DataFrame.add : Add DataFrames.
# DataFrame.sub : Subtract DataFrames.
# DataFrame.mul : Multiply DataFrames.
# DataFrame.div : Divide DataFrames

# %%
df["age"].sub(10)
# Out:
# 0     14
# 1     13
# 2     10
# 3     11
# 4      8
#       ..
# 95    22
# 96    24
# 97    11
# 98    10
# 99    11
# Name: age, Length: 100, dtype: int64

# %%
df["age"].mul(3)
# Out:
# 0      72
# 1      69
# 2      60
# 3      63
# 4      54
#      ...
# 95     96
# 96    102
# 97     63
# 98     60
# 99     63
# Name: age, Length: 100, dtype: int64

# %%
df["age"].div(3)
# Out:
# 0      8.000000
# 1      7.666667
# 2      6.666667
# 3      7.000000
# 4      6.000000
#         ...
# 95    10.666667
# 96    11.333333
# 97     7.000000
# 98     6.666667
# 99     7.000000
# Name: age, Length: 100, dtype: float64

# %%
df["age"]-10
# Out:
# 0     14
# 1     13
# 2     10
# 3     11
# 4      8
#       ..
# 95    22
# 96    24
# 97    11
# 98    10
# 99    11
# Name: age, Length: 100, dtype: int64

# %%
df["age"]*3
# Out:
# 0      72
# 1      69
# 2      60
# 3      63
# 4      54
#      ...
# 95     96
# 96    102
# 97     63
# 98     60
# 99     63
# Name: age, Length: 100, dtype: int64

# %%
df["age"]%4
# Out:
# 0     0
# 1     3
# 2     0
# 3     1
# 4     2
#      ..
# 95    0
# 96    2
# 97    1
# 98    0
# 99    1
# Name: age, Length: 100, dtype: int64

# %%
DataFrame.truediv : Divide DataFrames (float division).
DataFrame.floordiv : Divide DataFrames (integer division).
DataFrame.mod : Calculate modulo (remainder after division).
DataFrame.pow

# %%
df["age"].truediv(3)
# Out:
# 0      8.000000
# 1      7.666667
# 2      6.666667
# 3      7.000000
# 4      6.000000
#         ...
# 95    10.666667
# 96    11.333333
# 97     7.000000
# 98     6.666667
# 99     7.000000
# Name: age, Length: 100, dtype: float64

# %%
df["age"]/3
# Out:
# 0      8.000000
# 1      7.666667
# 2      6.666667
# 3      7.000000
# 4      6.000000
#         ...
# 95    10.666667
# 96    11.333333
# 97     7.000000
# 98     6.666667
# 99     7.000000
# Name: age, Length: 100, dtype: float64

# %%
df["age"]//3
# Out:
# 0      8
# 1      7
# 2      6
# 3      7
# 4      6
#       ..
# 95    10
# 96    11
# 97     7
# 98     6
# 99     7
# Name: age, Length: 100, dtype: int64

# %%
df["age"].floordiv(3)
# Out:
# 0      8
# 1      7
# 2      6
# 3      7
# 4      6
#       ..
# 95    10
# 96    11
# 97     7
# 98     6
# 99     7
# Name: age, Length: 100, dtype: int64

# %%
df["age"]%10
# Out:
# 0     4
# 1     3
# 2     0
# 3     1
# 4     8
#      ..
# 95    2
# 96    4
# 97    1
# 98    0
# 99    1
# Name: age, Length: 100, dtype: int64

# %%
df["age"].mod(10)
# Out:
# 0     4
# 1     3
# 2     0
# 3     1
# 4     8
#      ..
# 95    2
# 96    4
# 97    1
# 98    0
# 99    1
# Name: age, Length: 100, dtype: int64

# %%
df["age"]**3
# Out:
# 0     13824
# 1     12167
# 2      8000
# 3      9261
# 4      5832
#       ...
# 95    32768
# 96    39304
# 97     9261
# 98     8000
# 99     9261
# Name: age, Length: 100, dtype: int64

# %%
df["age"].pow(3)
# Out:
# 0     13824
# 1     12167
# 2      8000
# 3      9261
# 4      5832
#       ...
# 95    32768
# 96    39304
# 97     9261
# 98     8000
# 99     9261
# Name: age, Length: 100, dtype: int64

# %%
# method 1 -
# df["column"] = values
# if specified column is available then every value will be replaced 
# if not present then a new col will be added

# %%
import pandas as pd
l1 = [10,20,30,40]
l2 = ["nitin" , "tina" , "arun" ,"riya"]
l3 = [1000,2000,3000,4000]
l4 = ["doon" , "delhi" , "rishikesh" , "shimla"]

df2 = pd.DataFrame({"no":l1 , "name":l2 , "salary":l3 , "addrs":l4})

df2
# Out:
#    no   name  salary      addrs
# 0  10  nitin    1000       doon
# 1  20   tina    2000      delhi
# 2  30   arun    3000  rishikesh
# 3  40   riya    4000     shimla

# %%
df2["salary"] = 500

# %%
df2
# Out:
#    no   name  salary      addrs
# 0  10  nitin     500       doon
# 1  20   tina     500      delhi
# 2  30   arun     500  rishikesh
# 3  40   riya     500     shimla

# %%
df2["city"] = "noida"

# %%
df2
# Out:
#    no   name  salary      addrs   city
# 0  10  nitin     500       doon  noida
# 1  20   tina     500      delhi  noida
# 2  30   arun     500  rishikesh  noida
# 3  40   riya     500     shimla  noida

# %%
df2["city"] = ["noida","agra","delhi","doon" ]

# %%
df2
# Out:
#    no   name  salary      addrs   city
# 0  10  nitin     500       doon  noida
# 1  20   tina     500      delhi   agra
# 2  30   arun     500  rishikesh  delhi
# 3  40   riya     500     shimla   doon

# %%
df2.insert(2,"branch1",["cse","it" , "me","eee"])

# %%
df2
# Out:
#    no   name branch1 branch  salary      addrs   city
# 0  10  nitin     cse    cse     500       doon  noida
# 1  20   tina      it    cse     500      delhi   agra
# 2  30   arun      me    cse     500  rishikesh  delhi
# 3  40   riya     eee    cse     500     shimla   doon

# %%
import pandas as pd

df = pd.read_csv("emp.csv")
df
# Out:
#     eno   ename    esal       city
# 0  10.0  nikhil  7500.0      noida
# 1  20.0    tina  8500.0      delhi
# 2  30.0    arun  7000.0       doon
# 3  40.0   kajal  6000.0     shimla
# 4  50.0     NaN  4000.0       doon
# 5  60.0    renu  2500.0      delhi
# 6  70.0     NaN  1500.0     shimla
# 7  80.0    arun     NaN       doon
# 8  90.0    aman     NaN  rishikesh
# 9   NaN     NaN     NaN        NaN

# %%
df.dropna()
# Out:
#     eno   ename    esal    city
# 0  10.0  nikhil  7500.0   noida
# 1  20.0    tina  8500.0   delhi
# 2  30.0    arun  7000.0    doon
# 3  40.0   kajal  6000.0  shimla
# 5  60.0    renu  2500.0   delhi

# %%
df
# Out:
#     eno   ename    esal       city
# 0  10.0  nikhil  7500.0      noida
# 1  20.0    tina  8500.0      delhi
# 2  30.0    arun  7000.0       doon
# 3  40.0   kajal  6000.0     shimla
# 4  50.0     NaN  4000.0       doon
# 5  60.0    renu  2500.0      delhi
# 6  70.0     NaN  1500.0     shimla
# 7  80.0    arun     NaN       doon
# 8  90.0    aman     NaN  rishikesh
# 9   NaN     NaN     NaN        NaN

# %%
df.dropna(subset = ["city","esal"])
# Out:
#     eno   ename    esal    city
# 0  10.0  nikhil  7500.0   noida
# 1  20.0    tina  8500.0   delhi
# 2  30.0    arun  7000.0    doon
# 3  40.0   kajal  6000.0  shimla
# 4  50.0     NaN  4000.0    doon
# 5  60.0    renu  2500.0   delhi
# 6  70.0     NaN  1500.0  shimla

# %%
df.dropna(how = "all")
# Out:
#     eno   ename    esal       city
# 0  10.0  nikhil  7500.0      noida
# 1  20.0    tina  8500.0      delhi
# 2  30.0    arun  7000.0       doon
# 3  40.0   kajal  6000.0     shimla
# 4  50.0     NaN  4000.0       doon
# 5  60.0    renu  2500.0      delhi
# 6  70.0     NaN  1500.0     shimla
# 7  80.0    arun     NaN       doon
# 8  90.0    aman     NaN  rishikesh

# %%
df
# Out:
#     eno   ename    esal       city
# 0  10.0  nikhil  7500.0      noida
# 1  20.0    tina  8500.0      delhi
# 2  30.0    arun  7000.0       doon
# 3  40.0   kajal  6000.0     shimla
# 4  50.0     NaN  4000.0       doon
# 5  60.0    renu  2500.0      delhi
# 6  70.0     NaN  1500.0     shimla
# 7  80.0    arun     NaN       doon
# 8  90.0    aman     NaN  rishikesh
# 9   NaN     NaN     NaN        NaN

# %%
df.dropna(axis = 1 , how = "all")
# Out:
#     eno   ename    esal       city
# 0  10.0  nikhil  7500.0      noida
# 1  20.0    tina  8500.0      delhi
# 2  30.0    arun  7000.0       doon
# 3  40.0   kajal  6000.0     shimla
# 4  50.0     NaN  4000.0       doon
# 5  60.0    renu  2500.0      delhi
# 6  70.0     NaN  1500.0     shimla
# 7  80.0    arun     NaN       doon
# 8  90.0    aman     NaN  rishikesh
# 9   NaN     NaN     NaN        NaN

# %%
df
# Out:
#     eno   ename    esal       city
# 0  10.0  nikhil  7500.0      noida
# 1  20.0    tina  8500.0      delhi
# 2  30.0    arun  7000.0       doon
# 3  40.0   kajal  6000.0     shimla
# 4  50.0     NaN  4000.0       doon
# 5  60.0    renu  2500.0      delhi
# 6  70.0     NaN  1500.0     shimla
# 7  80.0    arun     NaN       doon
# 8  90.0    aman     NaN  rishikesh
# 9   NaN     NaN     NaN        NaN

# %%
df.fillna(20)
# Out:
#     eno   ename    esal       city
# 0  10.0  nikhil  7500.0      noida
# 1  20.0    tina  8500.0      delhi
# 2  30.0    arun  7000.0       doon
# 3  40.0   kajal  6000.0     shimla
# 4  50.0      20  4000.0       doon
# 5  60.0    renu  2500.0      delhi
# 6  70.0      20  1500.0     shimla
# 7  80.0    arun    20.0       doon
# 8  90.0    aman    20.0  rishikesh
# 9  20.0      20    20.0         20

# %%
df
# Out:
#     eno   ename    esal       city
# 0  10.0  nikhil  7500.0      noida
# 1  20.0    tina  8500.0      delhi
# 2  30.0    arun  7000.0       doon
# 3  40.0   kajal  6000.0     shimla
# 4  50.0     NaN  4000.0       doon
# 5  60.0    renu  2500.0      delhi
# 6  70.0     NaN  1500.0     shimla
# 7  80.0    arun     NaN       doon
# 8  90.0    aman     NaN  rishikesh
# 9   NaN     NaN     NaN        NaN

# %%
df["ename"].fillna("ram" , inplace = True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10388\2304435958.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["ename"].fillna("ram" , inplace = True)

# %%
df
# Out:
#     eno   ename    esal       city
# 0  10.0  nikhil  7500.0      noida
# 1  20.0    tina  8500.0      delhi
# 2  30.0    arun  7000.0       doon
# 3  40.0   kajal  6000.0     shimla
# 4  50.0     ram  4000.0       doon
# 5  60.0    renu  2500.0      delhi
# 6  70.0     ram  1500.0     shimla
# 7  80.0    arun     NaN       doon
# 8  90.0    aman     NaN  rishikesh
# 9   NaN     ram     NaN        NaN

# %%
df["ename"] = df["ename"].fillna("ram")

# %%
df
# Out:
#     eno   ename    esal       city
# 0  10.0  nikhil  7500.0      noida
# 1  20.0    tina  8500.0      delhi
# 2  30.0    arun  7000.0       doon
# 3  40.0   kajal  6000.0     shimla
# 4  50.0     ram  4000.0       doon
# 5  60.0    renu  2500.0      delhi
# 6  70.0     ram  1500.0     shimla
# 7  80.0    arun     NaN       doon
# 8  90.0    aman     NaN  rishikesh
# 9   NaN     ram     NaN        NaN

# %%
df
# Out:
#     eno   ename    esal       city
# 0  10.0  nikhil  7500.0      noida
# 1  20.0    tina  8500.0      delhi
# 2  30.0    arun  7000.0       doon
# 3  40.0   kajal  6000.0     shimla
# 4  50.0     ram  4000.0       doon
# 5  60.0    renu  2500.0      delhi
# 6  70.0     ram  1500.0     shimla
# 7  80.0    arun     NaN       doon
# 8  90.0    aman     NaN  rishikesh
# 9   NaN     ram     NaN        NaN

# %%
for i in df:
    print(i)
# Out:
# eno
# ename
# esal
# city

# %%
df = pd.read_csv("stud.csv")

# %%
df
# Out:
#      id     name  age gender  marks branch
# 0     1      Ram   24      m     95  civil
# 1     2    Shyam   23      m     80    eee
# 2     3     Sita   20      f     85     cs
# 3     4    Geeta   21      f     93    eee
# 4     5    Kamal   18      m     77     me
# ..  ...      ...  ...    ...    ...    ...
# 95   96    Sneha   32      f     59    eee
# 96   97    Sumit   34      m     50  civil
# 97   98  Aarunya   21      f     88  civil
# 98   99  Atharva   20      m     90     me
# 99  100    Kowid   21      m     92  civil
#
# [100 rows x 6 columns]

# %%
for i in df:
    print(i)
# Out:
# id
# name
# age
# gender
# marks
# branch

# %%
for i in df["name"]:
    print(i)
# Out:
# Ram
# Shyam
# Sita
# Geeta
# Kamal
# Parshu ram
# Shiv
# Sehwag
# Gautam
# Mitali
# Kapil
# Jhulan
# Neha
# Ravi
# Arun
# Monu
# Aarti
# Jyoti
# Sonu
# Kirti
# Mohit
# sahil
# Varun
# Arun
# Shubham
# Akshay
# Yogesh
# Kiran
# Priyanka
# Anjali
# Rohan
# Sohan
# Mohan
# Amrinder Kaur
# Surender
# Ravinder
# Rajvinder kaur Bhatti
# Suresh
# Santosh
# Devvrat
# Omvir
# Roshni
# Renu
# Varun
# Dheeraj
# Kamal
# Saroj
# Krishan
# Vishal
# Abhinav
# Sumedha
# Kirti
# Anukampa
# Pratishtha
# Parikshit
# Sneha
# Sumit
# Aarunya
# Atharva
# Kowid
# Arun
# Ram
# Parshu
# Geetanjali
# Shivam
# Mahender
# Virat
# Rahul
# Hardik
# Rishabh
# Mohit
# sahil
# Varun
# Arun
# Shubham
# Akshay
# Yogesh
# Kiran
# Priyanka
# Anjali
# Rohan
# Sohan
# Mohan
# Amrinder Kaur
# Surender
# Monu
# Aarti
# Jyoti
# Sonu
# Kirti
# Sumedha
# Kirti
# Anu
# Pratishtha
# Parikshit
# Sneha
# Sumit
# Aarunya
# Atharva
# Kowid

# %%
df["sum"]= df["age"]+df["marks"]

# %%
df
# Out:
#      id     name  age gender  marks branch  sum
# 0     1      Ram   24      m     95  civil  119
# 1     2    Shyam   23      m     80    eee  103
# 2     3     Sita   20      f     85     cs  105
# 3     4    Geeta   21      f     93    eee  114
# 4     5    Kamal   18      m     77     me   95
# ..  ...      ...  ...    ...    ...    ...  ...
# 95   96    Sneha   32      f     59    eee   91
# 96   97    Sumit   34      m     50  civil   84
# 97   98  Aarunya   21      f     88  civil  109
# 98   99  Atharva   20      m     90     me  110
# 99  100    Kowid   21      m     92  civil  113
#
# [100 rows x 7 columns]

# %%
mcount= 0
fcount= 0
for i in df["gender"]:
    if i =="m":
        mcount= mcount+1
    else:
        fcount=fcount+1

print("m=",mcount, "f=", fcount)
# Out:
# m= 63 f= 37

# %%
dict={}

for i in df["branch"]:
    if i in dict:
        dict[i] += 1
    else:
        dict[i] = 1
print(dict)
# Out:
# {'civil': 21, 'eee': 16, 'cs': 22, 'me': 14, 'ec': 11, 'it': 16}

# %%
d={}

for i in df["branch"]:
    d[i] = list(df["branch"]).count(i)
d
# Out:
# {'civil': 21, 'eee': 16, 'cs': 22, 'me': 14, 'ec': 11, 'it': 16}

# %%
df["branch"].value_counts()
# Out:
# branch
# cs       22
# civil    21
# eee      16
# it       16
# me       14
# ec       11
# Name: count, dtype: int64

# %%
df["name"].values
# Out:
# array(['Ram', 'Shyam', 'Sita', 'Geeta', 'Kamal', 'Parshu ram', 'Shiv',
#        'Sehwag', 'Gautam', 'Mitali', 'Kapil', 'Jhulan', 'Neha', 'Ravi',
#        'Arun', 'Monu', 'Aarti', 'Jyoti', 'Sonu', 'Kirti', 'Mohit',
#        'sahil', 'Varun', 'Arun', 'Shubham', 'Akshay', 'Yogesh', 'Kiran',
#        'Priyanka', 'Anjali', 'Rohan', 'Sohan', 'Mohan', 'Amrinder Kaur',
#        'Surender', 'Ravinder', 'Rajvinder kaur Bhatti', 'Suresh',
#        'Santosh', 'Devvrat', 'Omvir', 'Roshni', 'Renu', 'Varun',
#        'Dheeraj', 'Kamal', 'Saroj', 'Krishan', 'Vishal', 'Abhinav',
#        'Sumedha', 'Kirti', 'Anukampa', 'Pratishtha', 'Parikshit', 'Sneha',
#        'Sumit', 'Aarunya', 'Atharva', 'Kowid', 'Arun', 'Ram', 'Parshu',
#        'Geetanjali', 'Shivam', 'Mahender', 'Virat', 'Rahul', 'Hardik',
#        'Rishabh', 'Mohit', 'sahil', 'Varun', 'Arun', 'Shubham', 'Akshay',
#        'Yogesh', 'Kiran', 'Priyanka', 'Anjali', 'Rohan', 'Sohan', 'Mohan',
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("emp.csv")
df
# Out:
#     eno   ename    esal       city
# 0  10.0  nikhil  7500.0      noida
# 1  20.0    tina  8500.0      delhi
# 2  30.0    arun  7000.0       doon
# 3  40.0   kajal  6000.0     shimla
# 4  50.0     NaN  4000.0       doon
# 5  60.0    renu  2500.0      delhi
# 6  70.0     NaN  1500.0     shimla
# 7  80.0    arun     NaN       doon
# 8  90.0    aman     NaN  rishikesh
# 9   NaN     NaN     NaN        NaN

# %%
df[df["ename"].isnull()]
# Out:
#     eno ename    esal    city
# 4  50.0   NaN  4000.0    doon
# 6  70.0   NaN  1500.0  shimla
# 9   NaN   NaN     NaN     NaN

# %%
df[df["ename"].notnull()]
# Out:
#     eno   ename    esal       city
# 0  10.0  nikhil  7500.0      noida
# 1  20.0    tina  8500.0      delhi
# 2  30.0    arun  7000.0       doon
# 3  40.0   kajal  6000.0     shimla
# 5  60.0    renu  2500.0      delhi
# 7  80.0    arun     NaN       doon
# 8  90.0    aman     NaN  rishikesh

# %%
# selct all emp from doon and shimla where ename is missing but esal is available

# %%
df[df['ename'].isnull() & (df['esal'].notnull())]
# Out:
#     eno ename    esal    city
# 4  50.0   NaN  4000.0    doon
# 6  70.0   NaN  1500.0  shimla

# %%
df
# Out:
#     eno   ename    esal       city
# 0  10.0  nikhil  7500.0      noida
# 1  20.0    tina  8500.0      delhi
# 2  30.0    arun  7000.0       doon
# 3  40.0   kajal  6000.0     shimla
# 4  50.0     NaN  4000.0       doon
# 5  60.0    renu  2500.0      delhi
# 6  70.0     NaN  1500.0     shimla
# 7  80.0    arun     NaN       doon
# 8  90.0    aman     NaN  rishikesh
# 9   NaN     NaN     NaN        NaN

# %%
df = pd.read_csv("stud.csv")
df
# Out:
#      id     name  age gender  marks branch
# 0     1      Ram   24      m     95  civil
# 1     2    Shyam   23      m     80    eee
# 2     3     Sita   20      f     85     cs
# 3     4    Geeta   21      f     93    eee
# 4     5    Kamal   18      m     77     me
# ..  ...      ...  ...    ...    ...    ...
# 95   96    Sneha   32      f     59    eee
# 96   97    Sumit   34      m     50  civil
# 97   98  Aarunya   21      f     88  civil
# 98   99  Atharva   20      m     90     me
# 99  100    Kowid   21      m     92  civil
#
# [100 rows x 6 columns]

# %%
df[df["gender"]=="f"]
# Out:
#     id                   name  age gender  marks branch
# 2    3                   Sita   20      f     85     cs
# 3    4                  Geeta   21      f     93    eee
# 9   10                 Mitali   34      f     88     me
# 11  12                 Jhulan   27      f     64     me
# 12  13                   Neha   23      f     83     it
# 16  17                  Aarti   25      f     88  civil
# 17  18                  Jyoti   21      f     85     cs
# 19  20                  Kirti   28      f     82    eee
# 27  28                  Kiran   27      f     95     ec
# 28  29               Priyanka   28      f     82     ec
# 29  30                 Anjali   33      f     77    eee
# 33  34          Amrinder Kaur   32      f     78     ec
# 36  37  Rajvinder kaur Bhatti   26      f     76     cs
# 38  39                Santosh   34      f     77     cs
# 41  42                 Roshni   30      f     97     cs
# 42  43                   Renu   28      f     87     cs
# ...

# %%
df[df["branch"]=="cs"]
# Out:
#     id                   name  age gender  marks branch
# 2    3                   Sita   20      f     85     cs
# 5    6             Parshu ram   30      m     65     cs
# 8    9                 Gautam   28      m     97     cs
# 13  14                   Ravi   35      m     51     cs
# 17  18                  Jyoti   21      f     85     cs
# 32  33                  Mohan   33      m     55     cs
# 36  37  Rajvinder kaur Bhatti   26      f     76     cs
# 38  39                Santosh   34      f     77     cs
# 41  42                 Roshni   30      f     97     cs
# 42  43                   Renu   28      f     87     cs
# 50  51                Sumedha   30      f     85     cs
# 52  53               Anukampa   35      f     95     cs
# 58  59                Atharva   19      m     95     cs
# 63  64             Geetanjali   23      f     87     cs
# 69  70                Rishabh   24      m     62     cs
# 74  75                Shubham   18      m     85     cs
# ...

# %%
df[(df["branch"]=="cs") & (df["gender"]=="f")]
# Out:
#     id                   name  age gender  marks branch
# 2    3                   Sita   20      f     85     cs
# 17  18                  Jyoti   21      f     85     cs
# 36  37  Rajvinder kaur Bhatti   26      f     76     cs
# 38  39                Santosh   34      f     77     cs
# 41  42                 Roshni   30      f     97     cs
# 42  43                   Renu   28      f     87     cs
# 50  51                Sumedha   30      f     85     cs
# 52  53               Anukampa   35      f     95     cs
# 63  64             Geetanjali   23      f     87     cs
# 86  87                  Aarti   22      f     56     cs
# 89  90                  Kirti   25      f     74     cs
# 92  93                    Anu   26      f     55     cs
# 93  94             Pratishtha   22      f     74     cs

# %%
df[(df["branch"]=="cs")| (df["branch"]=="eee")]
# Out:
#     id                   name  age gender  marks branch
# 1    2                  Shyam   23      m     80    eee
# 2    3                   Sita   20      f     85     cs
# 3    4                  Geeta   21      f     93    eee
# 5    6             Parshu ram   30      m     65     cs
# 8    9                 Gautam   28      m     97     cs
# 13  14                   Ravi   35      m     51     cs
# 17  18                  Jyoti   21      f     85     cs
# 19  20                  Kirti   28      f     82    eee
# 25  26                 Akshay   29      m     92    eee
# 29  30                 Anjali   33      f     77    eee
# 30  31                  Rohan   35      m     68    eee
# 32  33                  Mohan   33      m     55     cs
# 34  35               Surender   26      m     43    eee
# 36  37  Rajvinder kaur Bhatti   26      f     76     cs
# 37  38                 Suresh   33      m     56    eee
# 38  39                Santosh   34      f     77     cs
# ...

# %%
df[df["branch"].isin(["eee","cs"])]
# Out:
#     id                   name  age gender  marks branch
# 1    2                  Shyam   23      m     80    eee
# 2    3                   Sita   20      f     85     cs
# 3    4                  Geeta   21      f     93    eee
# 5    6             Parshu ram   30      m     65     cs
# 8    9                 Gautam   28      m     97     cs
# 13  14                   Ravi   35      m     51     cs
# 17  18                  Jyoti   21      f     85     cs
# 19  20                  Kirti   28      f     82    eee
# 25  26                 Akshay   29      m     92    eee
# 29  30                 Anjali   33      f     77    eee
# 30  31                  Rohan   35      m     68    eee
# 32  33                  Mohan   33      m     55     cs
# 34  35               Surender   26      m     43    eee
# 36  37  Rajvinder kaur Bhatti   26      f     76     cs
# 37  38                 Suresh   33      m     56    eee
# 38  39                Santosh   34      f     77     cs
# ...

# %%
df[(df['city'].isin(["Doon", "Shimla"])) & (df['ename'].isnull()) & (df['esal'].notnull())]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'city'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ...

# %%
df
# Out:
#      id     name  age gender  marks branch
# 0     1      Ram   24      m     95  civil
# 1     2    Shyam   23      m     80    eee
# 2     3     Sita   20      f     85     cs
# 3     4    Geeta   21      f     93    eee
# 4     5    Kamal   18      m     77     me
# ..  ...      ...  ...    ...    ...    ...
# 95   96    Sneha   32      f     59    eee
# 96   97    Sumit   34      m     50  civil
# 97   98  Aarunya   21      f     88  civil
# 98   99  Atharva   20      m     90     me
# 99  100    Kowid   21      m     92  civil
#
# [100 rows x 6 columns]

# %%
for i in df:
    print(i)
# Out:
# us
# pwd

# %%
df["name"]
# Out:
# 0         Ram
# 1       Shyam
# 2        Sita
# 3       Geeta
# 4       Kamal
#        ...
# 95      Sneha
# 96      Sumit
# 97    Aarunya
# 98    Atharva
# 99      Kowid
# Name: name, Length: 100, dtype: object

# %%
for i in df["name"]:
    print(i)
# Out:
# Ram
# Shyam
# Sita
# Geeta
# Kamal
# Parshu ram
# Shiv
# Sehwag
# Gautam
# Mitali
# Kapil
# Jhulan
# Neha
# Ravi
# Arun
# Monu
# Aarti
# Jyoti
# Sonu
# Kirti
# Mohit
# sahil
# Varun
# Arun
# Shubham
# Akshay
# Yogesh
# Kiran
# Priyanka
# Anjali
# Rohan
# Sohan
# Mohan
# Amrinder Kaur
# Surender
# Ravinder
# Rajvinder kaur Bhatti
# Suresh
# Santosh
# Devvrat
# Omvir
# Roshni
# Renu
# Varun
# Dheeraj
# Kamal
# Saroj
# Krishan
# Vishal
# Abhinav
# Sumedha
# Kirti
# Anukampa
# Pratishtha
# Parikshit
# Sneha
# Sumit
# Aarunya
# Atharva
# Kowid
# Arun
# Ram
# Parshu
# Geetanjali
# Shivam
# Mahender
# Virat
# Rahul
# Hardik
# Rishabh
# Mohit
# sahil
# Varun
# Arun
# Shubham
# Akshay
# Yogesh
# Kiran
# Priyanka
# Anjali
# Rohan
# Sohan
# Mohan
# Amrinder Kaur
# Surender
# Monu
# Aarti
# Jyoti
# Sonu
# Kirti
# Sumedha
# Kirti
# Anu
# Pratishtha
# Parikshit
# Sneha
# Sumit
# Aarunya
# Atharva
# Kowid

# %%
import pandas as pd

eno = (10,20,30,40)
ename = ("nitin" , "tina" , "arun" ,"riya")
esal = (1000,2000,3000,4000)
eadrs = ("doon" , "delhi" , "rishikesh" , "shimla")

df = pd.DataFrame({"eno":eno , "ename":ename , "esal":esal , "eadrs":eadrs})

df
# Out:
#    eno  ename  esal      eadrs
# 0   10  nitin  1000       doon
# 1   20   tina  2000      delhi
# 2   30   arun  3000  rishikesh
# 3   40   riya  4000     shimla

# %%
import pandas as pd

l1 = [10,20,30,40]
l2 = ["nitin" , "tina" , "arun" ,"riya"]
l3 = [1000,2000,3000,4000]
l4 = ["doon" , "delhi" , "rishikesh" , "shimla"]

df2 = pd.DataFrame({"eno":l1 , "e name":l2 , "esal":l3 , "eadrs":l4})

df2.to_csv("suryam.csv" , index = False)

# %%
df2
# Out:
#    eno e name  esal      eadrs
# 0   10  nitin  1000       doon
# 1   20   tina  2000      delhi
# 2   30   arun  3000  rishikesh
# 3   40   riya  4000     shimla

# %%
pd.read_csv("suryam.csv")
# Out:
#    Unnamed: 0  eno e name  esal      eadrs
# 0           0   10  nitin  1000       doon
# 1           1   20   tina  2000      delhi
# 2           2   30   arun  3000  rishikesh
# 3           3   40   riya  4000     shimla

# %%
# task

# %%
import pandas as pd

# %%
df  = pd.read_csv("stud.csv")
df
# Out:
#      id     name  age gender  marks branch
# 0     1      Ram   24      m     95  civil
# 1     2    Shyam   23      m     80    eee
# 2     3     Sita   20      f     85     cs
# 3     4    Geeta   21      f     93    eee
# 4     5    Kamal   18      m     77     me
# ..  ...      ...  ...    ...    ...    ...
# 95   96    Sneha   32      f     59    eee
# 96   97    Sumit   34      m     50  civil
# 97   98  Aarunya   21      f     88  civil
# 98   99  Atharva   20      m     90     me
# 99  100    Kowid   21      m     92  civil
#
# [100 rows x 6 columns]

# %%
user = input("enter username = ")
psd =  int(input("enter paswrd = "))

user_exists = ((df['us'] == user) & (df['pwd'] == psd)).any()

if user_exists:
    print("Login successful!")
else:
    print("Invalid username or password")
# Out:
# enter username =  tina
# enter paswrd =  234
# Invalid username or password

# %%
df["us"][1]
# Out:
# 'arun'

# %%
for i in df.index:
    print(df["us"][i])
# Out:
# ram
# arun
# tina
# ankit
# riya

# %%
df
# Out:
#      id     name  age gender  marks branch
# 0     1      Ram   24      m     95  civil
# 1     2    Shyam   23      m     80    eee
# 2     3     Sita   20      f     85     cs
# 3     4    Geeta   21      f     93    eee
# 4     5    Kamal   18      m     77     me
# ..  ...      ...  ...    ...    ...    ...
# 95   96    Sneha   32      f     59    eee
# 96   97    Sumit   34      m     50  civil
# 97   98  Aarunya   21      f     88  civil
# 98   99  Atharva   20      m     90     me
# 99  100    Kowid   21      m     92  civil
#
# [100 rows x 6 columns]

# %%
import pandas as pd

# %%
df = pd.read_csv("file.csv")
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df[df["Release_Date"].notnull()]
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
for i in df[df["Release_Date"].notnull()]["Release_Date"]:
    print(i[-4::])
# Out:
# 2020
# 2016
# 2018
# 2017
# 2020
# 2017
# 2020
# 2019
# 2019
# 2017
# 2017
# 2018
# 2019
# 2019
# 2020
# 2019
# 2019
# 2018
# 2019
# 2018
# 2018
# 2018
# 2018
# 2018
# 2020
# 2016
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2020
# 2017
# 2019
# 2016
# 2019
# 2019
# 2019
# 2019
# 2017
# 2018
# 2017
# 2020
# 2018
# 2017
# 2017
# 2017
# 2019
# 2017
# 2019
# 2020
# 2018
# 2020
# 2017
# 2019
# 2018
# 2021
# 2019
# 2016
# 2019
# 2017
# 2016
# 2020
# 2019
# 2019
# 2016
# 2017
# 2019
# 2018
# 2019
# 2019
# 2021
# 2020
# 2017
# 2020
# 2019
# 2020
# 2018
# 2018
# 2017
# 2017
# 2018
# 2019
# 2019
# 2020
# 2018
# 2018
# 2018
# 2018
# 2018
# 2017
# 2018
# 2018
# 2020
# 2017
# 2020
# 2019
# 2017
# 2019
# 2019
# 2019
# 2016
# 2019
# 2021
# 2019
# 2020
# 2020
# 2019
# 2020
# 2018
# 2020
# 2019
# 2017
# 2019
# 2016
# 2020
# 2019
# 2019
# 2018
# 2017
# 2020
# 2019
# 2018
# 2020
# 2018
# 2018
# 2019
# 2015
# 2017
# 2020
# 2019
# 2019
# 2016
# 2018
# 2019
# 2018
# 2016
# 2018
# 2017
# 2016
# 2020
# ...

# %%
python

# %%
sql
powerbi
statistics

# %%
df1 = pd.read_csv("month1.csv")
df2 = pd.read_csv("month2.csv")

# %%
df1
# Out:
#    sid  cid
# 0    1    9
# 1   10    6
# 2    5    2
# 3    2    8

# %%
df2
# Out:
#    sid  cid
# 0    5   10
# 1    4    8
# 2    2    3
# 3    4    2
# 4    1    7

# %%
x = pd.concat([df1, df2])

# %%
x
# Out:
#    sid  cid
# 0    1    9
# 1   10    6
# 2    5    2
# 3    2    8
# 0    5   10
# 1    4    8
# 2    2    3
# 3    4    2
# 4    1    7

# %%
x.iloc[[1,2],:]
# Out:
#    sid  cid
# 1   10    6
# 2    5    2

# %%
y = pd.concat([df1, df2] , ignore_index = True)
y
# Out:
#    sid  cid
# 0    1    9
# 1   10    6
# 2    5    2
# 3    2    8
# 4    5   10
# 5    4    8
# 6    2    3
# 7    4    2
# 8    1    7

# %%
x = pd.concat([df1, df2])

# %%
x
# Out:
#    sid  cid
# 0    1    9
# 1   10    6
# 2    5    2
# 3    2    8
# 0    5   10
# 1    4    8
# 2    2    3
# 3    4    2
# 4    1    7

# %%
x.reset_index()
# Out:
#    index  sid  cid
# 0      0    1    9
# 1      1   10    6
# 2      2    5    2
# 3      3    2    8
# 4      0    5   10
# 5      1    4    8
# 6      2    2    3
# 7      3    4    2
# 8      4    1    7

# %%
# if we dont want old indexing

# %%
x.reset_index(drop = True)
# Out:
#    sid  cid
# 0    1    9
# 1   10    6
# 2    5    2
# 3    2    8
# 4    5   10
# 5    4    8
# 6    2    3
# 7    4    2
# 8    1    7

# %%
ar = pd.concat([df1,df2] , keys = ["month1" , "month2"])  
ar
# Out:
#           sid  cid
# month1 0    1    9
#        1   10    6
#        2    5    2
#        3    2    8
# month2 0    5   10
#        1    4    8
#        2    2    3
#        3    4    2
#        4    1    7

# %%
df1
# Out:
#    sid  cid
# 0    1    9
# 1   10    6
# 2    5    2
# 3    2    8

# %%
df2
# Out:
#    sid  cid
# 0    5   10
# 1    4    8
# 2    2    3
# 3    4    2
# 4    1    7

# %%
pd.concat([df1, df2] , axis = 1)
# Out:
#     sid  cid  sid  cid
# 0   1.0  9.0    5   10
# 1  10.0  6.0    4    8
# 2   5.0  2.0    2    3
# 3   2.0  8.0    4    2
# 4   NaN  NaN    1    7

# %%
df1 = pd.read_csv("month1.csv")
df2 = pd.read_csv("month3.csv")

# %%
df1
# Out:
#    sid  cid
# 0    1    9
# 1   10    6
# 2    5    2
# 3    2    8

# %%
df2
# Out:
#    sid  cid  mid
# 0    1    9   10
# 1    3    6   20
# 2    5    2   30
# 3    2    8   40

# %%
pd.concat([df1,df2])
# Out:
#    sid  cid   mid
# 0    1    9   NaN
# 1   10    6   NaN
# 2    5    2   NaN
# 3    2    8   NaN
# 0    1    9  10.0
# 1    3    6  20.0
# 2    5    2  30.0
# 3    2    8  40.0

# %%
pd.concat([df1,df2] , axis = 1)
# Out:
#    sid  cid  sid  cid  mid
# 0    1    9    1    9   10
# 1   10    6    3    6   20
# 2    5    2    5    2   30
# 3    2    8    2    8   40

# %%
pd.read_csv("stud.csv")
# Out:
#      id     name  age gender  marks branch
# 0     1      Ram   24      m     95  civil
# 1     2    Shyam   23      m     80    eee
# 2     3     Sita   20      f     85     cs
# 3     4    Geeta   21      f     93    eee
# 4     5    Kamal   18      m     77     me
# ..  ...      ...  ...    ...    ...    ...
# 95   96    Sneha   32      f     59    eee
# 96   97    Sumit   34      m     50  civil
# 97   98  Aarunya   21      f     88  civil
# 98   99  Atharva   20      m     90     me
# 99  100    Kowid   21      m     92  civil
#
# [100 rows x 6 columns]

# %%
df1 =  pd.read_csv("emp.csv")
df1
# Out:
#     eno   ename    esal       city
# 0  10.0  nikhil  7500.0      noida
# 1  20.0    tina  8500.0      delhi
# 2  30.0    arun  7000.0       doon
# 3  40.0   kajal  6000.0     shimla
# 4  50.0     NaN  4000.0       doon
# 5  60.0    renu  2500.0      delhi
# 6  70.0     NaN  1500.0     shimla
# 7  80.0    arun     NaN       doon
# 8  90.0    aman     NaN  rishikesh
# 9   NaN     NaN     NaN        NaN

# %%
df2 = pd.read_csv("city_pollution.csv")
df2
# Out:
#         city  pollution_rate
# 0      noida             120
# 1      delhi              90
# 2       doon              40
# 3  rishikesh              30
# 4     shimla              25

# %%
df1[df1["city"].isin(df2[df2["pollution_rate"]>70]["city"])]
# Out:
#     eno   ename    esal   city
# 0  10.0  nikhil  7500.0  noida
# 1  20.0    tina  8500.0  delhi
# 5  60.0    renu  2500.0  delhi

# %%
df = pd.read_csv("temp.csv")
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
df.groupby(["city"]).sum()
# Out:
#                                        day  temperature  windspeed  \
# city
# mumbai    1/1/20171/2/20171/3/20171/4/2017          354         37
# new york  1/1/20171/2/20171/3/20171/4/2017          129         32
# paris     1/1/20171/2/20171/3/20171/4/2017          191         51
#
#                             event
# city
# mumbai            SunnyFogFogRain
# new york       RainSunnySnowSunny
# paris     SunnyCloudyCloudyCloudy

# %%
df.groupby(["city" , "event"])["temperature"].mean()
# Out:
# city      event
# mumbai    Fog       86.000000
#           Rain      92.000000
#           Sunny     90.000000
# new york  Rain      32.000000
#           Snow      28.000000
#           Sunny     34.500000
# paris     Cloudy    48.666667
#           Sunny     45.000000
# Name: temperature, dtype: float64

# %%
import pandas as pd

# %%
df1 = pd.read_csv("month1.csv")
df2 = pd.read_csv("month2.csv")

# %%
df1
# Out:
#    sid  cid
# 0    1    9
# 1   10    6
# 2    5    2
# 3    2    8

# %%
df2
# Out:
#    sid  cid
# 0    5   10
# 1    4    8
# 2    2    3
# 3    4    2
# 4    1    7

# %%
df = pd.read_csv("stud.csv")
df
# Out:
#      id     name  age gender  marks branch
# 0     1      Ram   24      m     95  civil
# 1     2    Shyam   23      m     80    eee
# 2     3     Sita   20      f     85     cs
# 3     4    Geeta   21      f     93    eee
# 4     5    Kamal   18      m     77     me
# ..  ...      ...  ...    ...    ...    ...
# 95   96    Sneha   32      f     59    eee
# 96   97    Sumit   34      m     50  civil
# 97   98  Aarunya   21      f     88  civil
# 98   99  Atharva   20      m     90     me
# 99  100    Kowid   21      m     92  civil
#
# [100 rows x 6 columns]

# %%
df["age"][0]
df["age"][1]
# Out:
# 23

# %%
df[["age" , "name"]]
# Out:
#     age     name
# 0    24      Ram
# 1    23    Shyam
# 2    20     Sita
# 3    21    Geeta
# 4    18    Kamal
# ..  ...      ...
# 95   32    Sneha
# 96   34    Sumit
# 97   21  Aarunya
# 98   20  Atharva
# 99   21    Kowid
#
# [100 rows x 2 columns]

# %%
for i in df["age"]:
    print(i)
# Out:
# 24
# 23
# 20
# 21
# 18
# 30
# 35
# 31
# 28
# 34
# 25
# 27
# 23
# 35
# 34
# 26
# 25
# 21
# 32
# 28
# 27
# 21
# 31
# 25
# 26
# 29
# 30
# 27
# 28
# 33
# 35
# 22
# 33
# 32
# 26
# 34
# 26
# 33
# 34
# 35
# 33
# 30
# 28
# 27
# 25
# 24
# 21
# 22
# 28
# 34
# 30
# 32
# 35
# 18
# 18
# 20
# 27
# 18
# 19
# 20
# 33
# 22
# 35
# 23
# 26
# 35
# 34
# 33
# 28
# 24
# 22
# 27
# 23
# 21
# 18
# 25
# 32
# 22
# 33
# 23
# 25
# 25
# 22
# 25
# 34
# 32
# 22
# 23
# 27
# 25
# 24
# 26
# 26
# 22
# 21
# 32
# 34
# 21
# 20
# 21

# %%
for i in df.index:
    print(df["age"][i])
# Out:
# 24
# 23
# 20
# 21
# 18
# 30
# 35
# 31
# 28
# 34
# 25
# 27
# 23
# 35
# 34
# 26
# 25
# 21
# 32
# 28
# 27
# 21
# 31
# 25
# 26
# 29
# 30
# 27
# 28
# 33
# 35
# 22
# 33
# 32
# 26
# 34
# 26
# 33
# 34
# 35
# 33
# 30
# 28
# 27
# 25
# 24
# 21
# 22
# 28
# 34
# 30
# 32
# 35
# 18
# 18
# 20
# 27
# 18
# 19
# 20
# 33
# 22
# 35
# 23
# 26
# 35
# 34
# 33
# 28
# 24
# 22
# 27
# 23
# 21
# 18
# 25
# 32
# 22
# 33
# 23
# 25
# 25
# 22
# 25
# 34
# 32
# 22
# 23
# 27
# 25
# 24
# 26
# 26
# 22
# 21
# 32
# 34
# 21
# 20
# 21

# %%
df.head()
# Out:
#    id   name  age gender  marks branch
# 0   1    Ram   24      m     95  civil
# 1   2  Shyam   23      m     80    eee
# 2   3   Sita   20      f     85     cs
# 3   4  Geeta   21      f     93    eee
# 4   5  Kamal   18      m     77     me

# %%
df[df["gender"] == "m"]
# Out:
#      id        name  age gender  marks branch
# 0     1         Ram   24      m     95  civil
# 1     2       Shyam   23      m     80    eee
# 4     5       Kamal   18      m     77     me
# 5     6  Parshu ram   30      m     65     cs
# 6     7        Shiv   35      m     80     ec
# ..  ...         ...  ...    ...    ...    ...
# 88   89        Sonu   27      m     68    eee
# 94   95   Parikshit   21      m     80     cs
# 96   97       Sumit   34      m     50  civil
# 98   99     Atharva   20      m     90     me
# 99  100       Kowid   21      m     92  civil
#
# [63 rows x 6 columns]

# %%
df[df["branch"]=="cs"]
# Out:
#     id                   name  age gender  marks branch
# 2    3                   Sita   20      f     85     cs
# 5    6             Parshu ram   30      m     65     cs
# 8    9                 Gautam   28      m     97     cs
# 13  14                   Ravi   35      m     51     cs
# 17  18                  Jyoti   21      f     85     cs
# 32  33                  Mohan   33      m     55     cs
# 36  37  Rajvinder kaur Bhatti   26      f     76     cs
# 38  39                Santosh   34      f     77     cs
# 41  42                 Roshni   30      f     97     cs
# 42  43                   Renu   28      f     87     cs
# 50  51                Sumedha   30      f     85     cs
# 52  53               Anukampa   35      f     95     cs
# 58  59                Atharva   19      m     95     cs
# 63  64             Geetanjali   23      f     87     cs
# 69  70                Rishabh   24      m     62     cs
# 74  75                Shubham   18      m     85     cs
# ...

# %%
df[(df["branch"]=="cs") & (df["gender"]=="f")]
# Out:
#     id                   name  age gender  marks branch
# 2    3                   Sita   20      f     85     cs
# 17  18                  Jyoti   21      f     85     cs
# 36  37  Rajvinder kaur Bhatti   26      f     76     cs
# 38  39                Santosh   34      f     77     cs
# 41  42                 Roshni   30      f     97     cs
# 42  43                   Renu   28      f     87     cs
# 50  51                Sumedha   30      f     85     cs
# 52  53               Anukampa   35      f     95     cs
# 63  64             Geetanjali   23      f     87     cs
# 86  87                  Aarti   22      f     56     cs
# 89  90                  Kirti   25      f     74     cs
# 92  93                    Anu   26      f     55     cs
# 93  94             Pratishtha   22      f     74     cs

# %%
df[df["age"]<22]
# Out:
#      id        name  age gender  marks branch
# 2     3        Sita   20      f     85     cs
# 3     4       Geeta   21      f     93    eee
# 4     5       Kamal   18      m     77     me
# 17   18       Jyoti   21      f     85     cs
# 21   22       sahil   21      m     66     it
# 46   47       Saroj   21      f     67     it
# 53   54  Pratishtha   18      f     94     it
# 54   55   Parikshit   18      m     90  civil
# 55   56       Sneha   20      f     79     ec
# 57   58     Aarunya   18      f     98     it
# 58   59     Atharva   19      m     95     cs
# 59   60       Kowid   20      m     94  civil
# 73   74        Arun   21      m     77     me
# 74   75     Shubham   18      m     85     cs
# 94   95   Parikshit   21      m     80     cs
# 97   98     Aarunya   21      f     88  civil
# 98   99     Atharva   20      m     90     me
# 99  100       Kowid   21      m     92  civil

# %%
df[df["name"]=="Arun"]
# Out:
#     id  name  age gender  marks branch
# 14  15  Arun   34      m     91     it
# 23  24  Arun   25      m     67     me
# 60  61  Arun   33      m     90  civil
# 73  74  Arun   21      m     77     me

# %%
for i in df["age"]:
    if i<22:
        print(df.loc[i:i])
# Out:
#     id   name  age gender  marks branch
# 20  21  Mohit   27      m     74  civil
#     id   name  age gender  marks branch
# 21  22  sahil   21      m     66     it
#     id  name  age gender  marks branch
# 18  19  Sonu   32      m     78     it
#     id   name  age gender  marks branch
# 21  22  sahil   21      m     66     it
#     id   name  age gender  marks branch
# 21  22  sahil   21      m     66     it
#     id   name  age gender  marks branch
# 21  22  sahil   21      m     66     it
#     id  name  age gender  marks branch
# 18  19  Sonu   32      m     78     it
#     id  name  age gender  marks branch
# 18  19  Sonu   32      m     78     it
#     id   name  age gender  marks branch
# 20  21  Mohit   27      m     74  civil
#     id  name  age gender  marks branch
# 18  19  Sonu   32      m     78     it
#     id   name  age gender  marks branch
# 19  20  Kirti   28      f     82    eee
#     id   name  age gender  marks branch
# 20  21  Mohit   27      m     74  civil
# ...

# %%
for i in df["name"]:
    if i[0]=="A":
        print(i)
# Out:
# Arun
# Aarti
# Arun
# Akshay
# Anjali
# Amrinder Kaur
# Abhinav
# Anukampa
# Aarunya
# Atharva
# Arun
# Arun
# Akshay
# Anjali
# Amrinder Kaur
# Aarti
# Anu
# Aarunya
# Atharva

# %%
# 200 - 300 -> list , string , dict

# %%
l = ["tina" , "arun" , "tanya" , "naman","tripti"]
l
# Out:
# ['tina', 'arun', 'tanya', 'naman', 'tripti']

# %%
for i in l:
    if i[0]=="t":
        print(i)
# Out:
# tina
# tanya
# tripti

# %%
df
# Out:
#      id     name  age gender  marks branch
# 0     1      Ram   24      m     95  civil
# 1     2    Shyam   23      m     80    eee
# 2     3     Sita   20      f     85     cs
# 3     4    Geeta   21      f     93    eee
# 4     5    Kamal   18      m     77     me
# ..  ...      ...  ...    ...    ...    ...
# 95   96    Sneha   32      f     59    eee
# 96   97    Sumit   34      m     50  civil
# 97   98  Aarunya   21      f     88  civil
# 98   99  Atharva   20      m     90     me
# 99  100    Kowid   21      m     92  civil
#
# [100 rows x 6 columns]

# %%
f = 0
m = 0

for i in df["gender"]:
    if i == "m":
        m = m+1
    else:
        f = f+1
m
# Out:
# 63

# %%
f
# Out:
# 37

# %%
df["gender"].value_counts()
# Out:
# gender
# m    63
# f    37
# Name: count, dtype: int64

# %%
df
# Out:
#      id     name  age gender  marks branch
# 0     1      Ram   24      m     95  civil
# 1     2    Shyam   23      m     80    eee
# 2     3     Sita   20      f     85     cs
# 3     4    Geeta   21      f     93    eee
# 4     5    Kamal   18      m     77     me
# ..  ...      ...  ...    ...    ...    ...
# 95   96    Sneha   32      f     59    eee
# 96   97    Sumit   34      m     50  civil
# 97   98  Aarunya   21      f     88  civil
# 98   99  Atharva   20      m     90     me
# 99  100    Kowid   21      m     92  civil
#
# [100 rows x 6 columns]

# %%
dict= {}
for i in df["branch"]:
    if i in dict:
        dict[i]+=1
    else:
        dict[i]=1
print(dict)
# Out:
# {'civil': 21, 'eee': 16, 'cs': 22, 'me': 14, 'ec': 11, 'it': 16}

# %%
df.groupby(["branch"])["age"].sum()
# Out:
# branch
# civil    565
# cs       572
# ec       308
# eee      460
# it       408
# me       369
# Name: age, dtype: int64

# %%
df
# Out:
#      id     name  age gender  marks branch
# 0     1      Ram   24      m     95  civil
# 1     2    Shyam   23      m     80    eee
# 2     3     Sita   20      f     85     cs
# 3     4    Geeta   21      f     93    eee
# 4     5    Kamal   18      m     77     me
# ..  ...      ...  ...    ...    ...    ...
# 95   96    Sneha   32      f     59    eee
# 96   97    Sumit   34      m     50  civil
# 97   98  Aarunya   21      f     88  civil
# 98   99  Atharva   20      m     90     me
# 99  100    Kowid   21      m     92  civil
#
# [100 rows x 6 columns]

# %%
df["Total"] = df["age"] + df["marks"]

# %%
df
# Out:
#      id     name  age gender  marks branch  Total
# 0     1      Ram   24      m     95  civil    119
# 1     2    Shyam   23      m     80    eee    103
# 2     3     Sita   20      f     85     cs    105
# 3     4    Geeta   21      f     93    eee    114
# 4     5    Kamal   18      m     77     me     95
# ..  ...      ...  ...    ...    ...    ...    ...
# 95   96    Sneha   32      f     59    eee     91
# 96   97    Sumit   34      m     50  civil     84
# 97   98  Aarunya   21      f     88  civil    109
# 98   99  Atharva   20      m     90     me    110
# 99  100    Kowid   21      m     92  civil    113
#
# [100 rows x 7 columns]

# %%
reversed_names = []
for name in df["name"]:
    reversed_names.append(name[::-1])

df["reversed_name"] = reversed_names

# %%
df
# Out:
#      id     name  age gender  marks branch  Total reversed_name
# 0     1      Ram   24      m     95  civil    119           maR
# 1     2    Shyam   23      m     80    eee    103         mayhS
# 2     3     Sita   20      f     85     cs    105          atiS
# 3     4    Geeta   21      f     93    eee    114         ateeG
# 4     5    Kamal   18      m     77     me     95         lamaK
# ..  ...      ...  ...    ...    ...    ...    ...           ...
# 95   96    Sneha   32      f     59    eee     91         ahenS
# 96   97    Sumit   34      m     50  civil     84         timuS
# 97   98  Aarunya   21      f     88  civil    109       aynuraA
# 98   99  Atharva   20      m     90     me    110       avrahtA
# 99  100    Kowid   21      m     92  civil    113         diwoK
#
# [100 rows x 8 columns]

# %%
df["reversed_name"] = 0

# %%
for i in df.index:
    df["reversed_name"][i] = df["name"][i][::-1]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15308\4118819323.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["reversed_name"][i] = df["name"][i][::-1]
# ...

# %%
df
# Out:
#      id     name  age gender  marks branch  Total reversed_name
# 0     1      Ram   24      m     95  civil    119           maR
# 1     2    Shyam   23      m     80    eee    103         mayhS
# 2     3     Sita   20      f     85     cs    105          atiS
# 3     4    Geeta   21      f     93    eee    114         ateeG
# 4     5    Kamal   18      m     77     me     95         lamaK
# ..  ...      ...  ...    ...    ...    ...    ...           ...
# 95   96    Sneha   32      f     59    eee     91         ahenS
# 96   97    Sumit   34      m     50  civil     84         timuS
# 97   98  Aarunya   21      f     88  civil    109       aynuraA
# 98   99  Atharva   20      m     90     me    110       avrahtA
# 99  100    Kowid   21      m     92  civil    113         diwoK
#
# [100 rows x 8 columns]
