# %%
# airthemetic operations

# %%
# we can not apply airthmetic opratns directly on dataframe object bcoz it contains
# multiple cols
# but we can perform airthemetic operations by selecting a particulr colmn of dataframe
# bcoz each col of dataframe is a series

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("emp.csv")
df
# Out:
#    eno   ename    esal       city
# 0   10  nikhil  7500.0      noida
# 1   20    tina  8500.0      delhi
# 2   30    arun  7000.0       doon
# 3   40   kajal  6000.0     shimla
# 4   50     NaN  4000.0       doon
# 5   60    renu  2500.0      delhi
# 6   70     NaN  1500.0     shimla
# 7   80    arun     NaN       doon
# 8   90    aman     NaN  rishikesh
# 9   10   nitin  7500.0      noida

# %%
# add 500 value to the esal column value

# %%
df["esal"]+500
# Out:
# 0    8000.0
# 1    9000.0
# 2    7500.0
# 3    6500.0
# 4    4500.0
# 5    3000.0
# 6    2000.0
# 7       NaN
# 8       NaN
# 9    8000.0
# Name: esal, dtype: float64

# %%
df["esal"].add(300)
# Out:
# 0    7800.0
# 1    8800.0
# 2    7300.0
# 3    6300.0
# 4    4300.0
# 5    2800.0
# 6    1800.0
# 7       NaN
# 8       NaN
# 9    7800.0
# Name: esal, dtype: float64

# %%
# or
df.esal.add(500)
# Out:
# 0    1500
# 1    2500
# 2    3500
# 3    4500
# 4    5500
# Name: esal, dtype: int64

# %%
# same for sub(-) , mul(*), div (/)

# %%
True + 1
# Out:
# 2

# %% [markdown]
# # how to add new columns to the dataframe

# %%
# method 1 -
# df["column"] = values
# if specified column is available then every value will be replaced 
# if not present then a new col will be added

# %%
import pandas as pd

df = pd.read_csv("emp.csv")
df
# Out:
#    eno   ename    esal       city
# 0   10  nikhil  7500.0      noida
# 1   20    tina  8500.0      delhi
# 2   30    arun  7000.0       doon
# 3   40   kajal  6000.0     shimla
# 4   50     NaN  4000.0       doon
# 5   60    renu  2500.0      delhi
# 6   70     NaN  1500.0     shimla
# 7   80    arun     NaN       doon
# 8   90    aman     NaN  rishikesh
# 9   10   nitin  7500.0      noida

# %%
df["esal"] = 666

# %%
#df.esal = 777

# %%
df
# Out:
#    eno   ename  esal       city
# 0   10  nikhil   666      noida
# 1   20    tina   666      delhi
# 2   30    arun   666       doon
# 3   40   kajal   666     shimla
# 4   50     NaN   666       doon
# 5   60    renu   666      delhi
# 6   70     NaN   666     shimla
# 7   80    arun   666       doon
# 8   90    aman   666  rishikesh
# 9   10   nitin   666      noida

# %%
# if col is not available

# %%
import pandas as pd

eno = [10,20,30,40 , 50]
ename = ["nitin" , "tina" , "arun" ,"riya" ,None]
esal = [1000,2000,3000,4000 , 5000]
eadrs = ["doon" , "delhi" , "rishikesh" , "shimla" , pd.NA]

df = pd.DataFrame({"eno":eno , "ename":ename , "esal":esal , "eadrs":eadrs})

df
# Out:
#    eno  ename  esal      eadrs
# 0   10  nitin  1000       doon
# 1   20   tina  2000      delhi
# 2   30   arun  3000  rishikesh
# 3   40   riya  4000     shimla
# 4   50   None  5000       <NA>

# %%
df["country"] = "india"

# %%
df
# Out:
#    eno  ename  esal      eadrs country
# 0   10  nitin  1000       doon   india
# 1   20   tina  2000      delhi   india
# 2   30   arun  3000  rishikesh   india
# 3   40   riya  4000     shimla   india
# 4   50   None  5000       <NA>   india

# %%
# if we try
# df["country"] = ["india" , "china"] - invalid
# we must provide same no of  values

# %%
df["country"] = ["india" , "china" , "nepal" , "canada" , "london"]

# %%
df
# Out:
#    eno  ename  esal      eadrs country
# 0   10  nitin  1000       doon   india
# 1   20   tina  2000      delhi   china
# 2   30   arun  3000  rishikesh   nepal
# 3   40   riya  4000     shimla  canada
# 4   50   None  5000       <NA>  london

# %%
# method 2

# insert() - insert col to dataframe at specified location

# %%
import pandas as pd

df = pd.read_csv("emp.csv")
df
# Out:
#    eno  ename  esal      eadrs
# 0   10  nitin  1000       doon
# 1   20   tina  2000      delhi
# 2   30   arun  3000  rishikesh
# 3   40   riya  4000     shimla
# 4   50  tannu  5000       agra

# %%
# df.insert(1 , "esal" , 777) - invalid  as esal already exist

# %%
df.insert(2,"country" , "india")

# %%
df
# Out:
#    eno  ename country  esal      eadrs
# 0   10  nitin   india  1000       doon
# 1   20   tina   india  2000      delhi
# 2   30   arun   india  3000  rishikesh
# 3   40   riya   india  4000     shimla
# 4   50  tannu   india  5000       agra

# %%
# how to drop rows with missing / null values

# dropna() method

# %%
import pandas as pd

df = pd.read_csv("emp.csv")
df
# Out:
#    eno   ename    esal       city
# 0   10  nikhil  7500.0      noida
# 1   20    tina  8500.0      delhi
# 2   30    arun  7000.0       doon
# 3   40   kajal  6000.0     shimla
# 4   50     NaN  4000.0       doon
# 5   60    renu  2500.0      delhi
# 6   70     NaN  1500.0     shimla
# 7   80    arun     NaN       doon
# 8   90    aman     NaN  rishikesh
# 9   10   nitin  7500.0      noida

# %%
# df.dropna() - by default it  removes rows from the dataframe where atleast one missing value

# %%
df.dropna()
# Out:
#     eno  ename    esal      eadrs
# 0  10.0  nitin  1000.0       doon
# 1  20.0   tina  2000.0      delhi
# 2  30.0   arun  3000.0  rishikesh
# 3  40.0   riya  4000.0     shimla
# 4  50.0  tannu  5000.0       agra

# %%
# how parameter --> 
# any - if any na values are present , drop that row 
# all - if all values are na , drop that row

# %%
df.dropna(how = "any")

#df.dropna(how = "all")
# Out:
#     eno  ename    esal      eadrs
# 0  10.0  nitin  1000.0       doon
# 1  20.0   tina  2000.0      delhi
# 2  30.0   arun  3000.0  rishikesh
# 3  40.0   riya  4000.0     shimla
# 4  50.0  tannu  5000.0       agra

# %%
# subset parameter
# to delte rows if par col has missing values

# only for dltng rows

# %%
import pandas as pd

df = pd.read_csv("emp.csv")
df
# Out:
#     eno  ename    esal      eadrs
# 0  10.0  nitin  1000.0       doon
# 1  20.0   tina  2000.0      delhi
# 2  30.0   arun  3000.0  rishikesh
# 3  40.0   riya  4000.0     shimla
# 4  50.0  tannu  5000.0       agra
# 5  60.0   renu     NaN      noida
# 6  70.0  shiva  7000.0        NaN
# 7   NaN    NaN     NaN        NaN

# %%
df.dropna(subset = ["esal" , "eadrs"])
# Out:
#     eno  ename    esal      eadrs
# 0  10.0  nitin  1000.0       doon
# 1  20.0   tina  2000.0      delhi
# 2  30.0   arun  3000.0  rishikesh
# 3  40.0   riya  4000.0     shimla
# 4  50.0  tannu  5000.0       agra

# %%
df.dropna(subset = ["esal"])
# Out:
#     eno  ename    esal      eadrs
# 0  10.0  nitin  1000.0       doon
# 1  20.0   tina  2000.0      delhi
# 2  30.0   arun  3000.0  rishikesh
# 3  40.0   riya  4000.0     shimla
# 4  50.0  tannu  5000.0       agra
# 6  70.0  shiva  7000.0        NaN

# %%
# how to delete columns which are having missing values

# we have to use axis = 1 or axis = "columns"

# %%
import pandas as pd

df = pd.read_csv("emp.csv")
df
# Out:
#    eno  ename    esal      eadrs
# 0   10  nitin  1000.0       doon
# 1   20   tina  2000.0      delhi
# 2   30   arun  3000.0  rishikesh
# 3   40   riya  4000.0     shimla
# 4   50  tannu  5000.0       agra
# 5   60   renu     NaN      noida
# 6   70  shiva  7000.0        NaN

# %%
df.dropna(axis = 1 )
# Out:
#    eno  ename
# 0   10  nitin
# 1   20   tina
# 2   30   arun
# 3   40   riya
# 4   50  tannu
# 5   60   renu
# 6   70  shiva

# %%
df["x"] = np.NaN

# %%
df
# Out:
#    eno  ename    esal      eadrs   x
# 0   10  nitin  1000.0       doon NaN
# 1   20   tina  2000.0      delhi NaN
# 2   30   arun  3000.0  rishikesh NaN
# 3   40   riya  4000.0     shimla NaN
# 4   50  tannu  5000.0       agra NaN
# 5   60   renu     NaN      noida NaN
# 6   70  shiva  7000.0        NaN NaN

# %%
df.dropna(axis=  1 , how = "all")
# Out:
#    eno  ename    esal      eadrs
# 0   10  nitin  1000.0       doon
# 1   20   tina  2000.0      delhi
# 2   30   arun  3000.0  rishikesh
# 3   40   riya  4000.0     shimla
# 4   50  tannu  5000.0       agra
# 5   60   renu     NaN      noida
# 6   70  shiva  7000.0        NaN

# %%
df
# Out:
#    eno  ename    esal      eadrs   x
# 0   10  nitin  1000.0       doon NaN
# 1   20   tina  2000.0      delhi NaN
# 2   30   arun  3000.0  rishikesh NaN
# 3   40   riya  4000.0     shimla NaN
# 4   50  tannu  5000.0       agra NaN
# 5   60   renu     NaN      noida NaN
# 6   70  shiva  7000.0        NaN NaN

# %%
df.dropna(subset = ["esal"] )
# Out:
#    eno  ename  esal      eadrs country
# 0   10  nitin  1000       doon   india
# 1   20   tina  2000      delhi   china
# 2   30   arun  3000  rishikesh   nepal
# 3   40   riya  4000     shimla  canada
# 4   50   None  5000       <NA>  london

# %% [markdown]
# # fill null values

# %%
# how to fill missing / null values with our required value in dataframe

# %%
# fillna()

# %%
import pandas as pd

# %%
df = pd.read_csv("fill.csv")
df
# Out:
#    eno  ename    esal      eadrs
# 0   10  nitin  1000.0       doon
# 1   20   tina  2000.0      delhi
# 2   30   arun  3000.0  rishikesh
# 3   40   riya  4000.0     shimla
# 4   50  tannu  5000.0       agra
# 5   60   renu     NaN      noida
# 6   70  shiva  7000.0        NaN
# 7   80    NaN     NaN        NaN

# %%
df.fillna(0)
# Out:
#    eno  ename    esal      eadrs
# 0   10  nitin  1000.0       doon
# 1   20   tina  2000.0      delhi
# 2   30   arun  3000.0  rishikesh
# 3   40   riya  4000.0     shimla
# 4   50  tannu  5000.0       agra
# 5   60   renu     0.0      noida
# 6   70  shiva  7000.0          0
# 7   80      0     0.0          0

# %%
# but this is meaning less as adrs col should not contain 0 as it takes string value

# %%
# replace ename with arun
# replace eadrs with rishikesh
# replace esal with 0

# %%
df["ename"] = df["ename"].fillna("arun")

# %%
df
# Out:
#    eno  ename    esal      eadrs
# 0   10  nitin  1000.0       doon
# 1   20   tina  2000.0      delhi
# 2   30   arun  3000.0  rishikesh
# 3   40   riya  4000.0     shimla
# 4   50  tannu  5000.0       agra
# 5   60   renu     NaN      noida
# 6   70  shiva  7000.0        NaN
# 7   80   arun     NaN        NaN

# %%
# for temporary

df["ename"].fillna("arun")
# Out:
# 0    nitin
# 1     tina
# 2     arun
# 3     riya
# 4    tannu
# 5     renu
# 6    shiva
# 7     arun
# Name: ename, dtype: object

# %%
# or for permanent

df["eadrs"].fillna("rishikesh" , inplace = True)

# %%
df
# Out:
#    eno  ename    esal      eadrs
# 0   10  nitin  1000.0       doon
# 1   20   tina  2000.0      delhi
# 2   30   arun  3000.0  rishikesh
# 3   40   riya  4000.0     shimla
# 4   50  tannu  5000.0       agra
# 5   60   renu     NaN      noida
# 6   70  shiva  7000.0  rishikesh
# 7   80   arun     NaN  rishikesh

# %%
df["esal"].fillna(0 , inplace = True)

# %%
df
# Out:
#    eno  ename    esal      eadrs
# 0   10  nitin  1000.0       doon
# 1   20   tina  2000.0      delhi
# 2   30   arun  3000.0  rishikesh
# 3   40   riya  4000.0     shimla
# 4   50  tannu  5000.0       agra
# 5   60   renu     0.0      noida
# 6   70  shiva  7000.0  rishikesh
# 7   80   arun     0.0  rishikesh

# %%
########################

# %%
df = pd.read_csv("emp.csv")
df
# Out:
#    eno  ename    esal      eadrs
# 0   10  nitin  1000.0       doon
# 1   20   tina  2000.0      delhi
# 2   30   arun  3000.0  rishikesh
# 3   40   riya  4000.0     shimla
# 4   50  tannu  5000.0       agra
# 5   60   renu     NaN      noida
# 6   70  shiva  7000.0        NaN

# %%
# here esal contain float value as nan is there in this col

# nan by default take float value which wastes memory

# %%
# frst need to drop nan values

# %%
df = df.dropna()
df
# Out:
#    eno  ename    esal      eadrs
# 0   10  nitin  1000.0       doon
# 1   20   tina  2000.0      delhi
# 2   30   arun  3000.0  rishikesh
# 3   40   riya  4000.0     shimla
# 4   50  tannu  5000.0       agra

# %%
df["esal"] = df["esal"].astype("int")
# Out:
# <ipython-input-45-19b5fdeffb19>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["esal"] = df["esal"].astype("int")

# %%
df
# Out:
#    eno  ename  esal      eadrs
# 0   10  nitin  1000       doon
# 1   20   tina  2000      delhi
# 2   30   arun  3000  rishikesh
# 3   40   riya  4000     shimla
# 4   50  tannu  5000       agra

# %%
gender    smoker      age    insurance

m           yes        40      no
f           yes        17      yes
m            no        30       yes
f            no        30       yes
f           yes        13       yes
